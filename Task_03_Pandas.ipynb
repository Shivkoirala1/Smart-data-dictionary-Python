# %% [markdown]
# ## Basic DataFrame

# %%
# install pandas if not

# %%
# import the required library
import pandas as pd

# %%
# Read a dataset named: 'imdb-top-1000' and show top 5 rows
import pandas as pd
df = pd.read_csv('imdb-top-1000.csv')

print(df.head(5))
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
# How many movies are in the dataset?
df.shape[0]
# Out:
# 1000

# %%
# What are the column names?
df.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='str')

# %%
# Provide dataset information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   str
#  1   Released_Year  1000 non-null   str
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   str
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   str
#  6   Star1          1000 non-null   str
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), str(5)
# memory usage: 129.5 KB

# %%
# What about statistical summary
df.describe()
# Out:
#            Runtime  IMDB_Rating   No_of_Votes         Gross   Metascore
# count  1000.000000  1000.000000  1.000000e+03  1.000000e+03  843.000000
# mean    122.891000     7.949300  2.736929e+05  1.282781e+08   77.971530
# std      28.093671     0.275491  3.273727e+05  2.011110e+08   12.376099
# min      45.000000     7.600000  2.508800e+04  1.305000e+03   28.000000
# 25%     103.000000     7.700000  5.552625e+04  5.012919e+06   70.000000
# 50%     119.000000     7.900000  1.385485e+05  3.953432e+07   79.000000
# 75%     137.000000     8.100000  3.741612e+05  1.615997e+08   87.000000
# max     321.000000     9.300000  2.343110e+06  9.366622e+08  100.000000

# %%
# Check if there is any missing values
df.isna().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Director           0
# Star1              0
# No_of_Votes        0
# Gross              0
# Metascore        157
# dtype: int64

# %%
# Fill the missing value with the mean of that particular column
df["Metascore"].fillna(df["Metascore"].mean())
# Out:
# 0       80.0
# 1      100.0
# 2       84.0
# 3       90.0
# 4       96.0
#        ...
# 995     76.0
# 996     84.0
# 997     85.0
# 998     78.0
# 999     93.0
# Name: Metascore, Length: 1000, dtype: float64

# %%
# df["Metascore"].isna().sum()
df.isna().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Director           0
# Star1              0
# No_of_Votes        0
# Gross              0
# Metascore        157
# dtype: int64

# %%
df["Metascore"] = df["Metascore"].fillna(df["Metascore"].mean())
df["Metascore"]
# Out:
# 0       80.0
# 1      100.0
# 2       84.0
# 3       90.0
# 4       96.0
#        ...
# 995     76.0
# 996     84.0
# 997     85.0
# 998     78.0
# 999     93.0
# Name: Metascore, Length: 1000, dtype: float64

# %%
df["Metascore"].isna().sum
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Metascore, Length: 1000, dtype: bool>

# %%
# Show movies with rating above 9
df[df["IMDB_Rating"]>9] [["Series_Title", "IMDB_Rating"]]
# Out:
#                Series_Title  IMDB_Rating
# 0  The Shawshank Redemption          9.3
# 1             The Godfather          9.2

# %%
# Show 10 most rated movies
df.sort_values("IMDB_Rating", ascending = False).head(10)
# esma aaba chaine chaine matra nikalne aafei garnu
# Out:
#                                     Series_Title Released_Year  Runtime  \
# 0                       The Shawshank Redemption          1994      142
# 1                                  The Godfather          1972      175
# 2                                The Dark Knight          2008      152
# 3                         The Godfather: Part II          1974      202
# 4                                   12 Angry Men          1957       96
# 5  The Lord of the Rings: The Return of the King          2003      201
# 6                                   Pulp Fiction          1994      154
# 7                               Schindler's List          1993      195
# 8                                      Inception          2010      148
# 9                                     Fight Club          1999      139
#
#        Genre  IMDB_Rating              Director              Star1  \
# 0      Drama          9.3        Frank Darabont        Tim Robbins
# ...

# %%
# Show number of movies done by each star
df["Star1"].value_counts()
# Out:
# Star1
# Tom Hanks            12
# Robert De Niro       11
# Al Pacino            10
# Clint Eastwood       10
# Leonardo DiCaprio     9
#                      ..
# Phil Harris           1
# David Hemmings        1
# John Lennon           1
# Tallulah Bankhead     1
# Robert Donat          1
# Name: count, Length: 660, dtype: int64

# %% [markdown]
# ## GroupBy

# %%
# Group all data based on "Genre"
Genre = df.groupby("Genre")
Genre
for item in Genre:
    print(Genre)

# %%
# groups
Genre.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
# find total number of groups -> len
len(Genre)
# Out:
# 14

# %%
# find items in each group -> size
Genre.size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
# first()/last()/nth() item
Genre.last()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
Genre.last()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
Genre.nth(5)
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 14                                          The Matrix          1999      136
# 24                                 Saving Private Ryan          1998      169
# 25                                      The Green Mile          1999      189
# 54                           Ayla: The Daughter of War          2017      125
# 61                                                Coco          2017      105
# 78   Dr. Strangelove or: How I Learned to Stop Worr...          1964       95
# 116                                 Lawrence of Arabia          1962      228
# 393                                     Twelve Monkeys          1995      129
# 707                                      The Innocents          1961      100
#
#          Genre  IMDB_Rating          Director            Star1  No_of_Votes  \
# 14      Action          8.7    Lana Wachowski  Lilly Wachowski      1676426
# ...

# %%
# get_group
Genre.get_group("Animation")
# Out:
#                           Series_Title Released_Year  Runtime      Genre  \
# 23       Sen to Chihiro no kamikakushi          2001      125  Animation
# 43                       The Lion King          1994       88  Animation
# 46                      Hotaru no haka          1988       89  Animation
# 56                      Kimi no na wa.          2016      106  Animation
# 58   Spider-Man: Into the Spider-Verse          2018      117  Animation
# ..                                 ...           ...      ...        ...
# 956                              Mulan          1998       88  Animation
# 971                  Omohide poro poro          1991      118  Animation
# 976                 The Little Mermaid          1989       83  Animation
# 986                     Watership Down          1978       91  Animation
# 992                    The Jungle Book          1967       78  Animation
#
#      IMDB_Rating             Director             Star1  No_of_Votes  \
# ...

# %%
# Compute mean for all numerical columns for each genre
Genre.mean(numeric_only= True)
# Out:
#               Runtime  IMDB_Rating    No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419  420246.581395  1.897224e+08  74.187060
# Adventure  134.111111     7.937500  313557.819444  1.319017e+08  78.385726
# Animation   99.585366     7.930488  268032.073171  1.784326e+08  80.826838
# Biography  136.022727     7.938636  272805.045455  9.404952e+07  76.417543
# Comedy     112.129032     7.901290  178195.658065  1.010572e+08  78.575135
# Crime      126.392523     8.016822  313398.271028  7.899656e+07  77.247015
# Drama      124.737024     7.957439  212343.612457  1.225259e+08  79.413957
# Family     107.500000     7.800000  275610.500000  2.195553e+08  79.000000
# Fantasy     85.000000     8.000000   73111.000000  3.913633e+08  77.971530
# Film-Noir  104.000000     7.966667  122405.000000  4.197018e+07  95.666667
# Horror     102.090909     7.909091  340232.363636  9.405902e+07  80.000000
# ...

# %%
# Find top 3 genre by total earning
Genre["Gross"].sum().sort_values().tail(3)
# Out:
# Genre
# Comedy    1.566387e+10
# Action    3.263226e+10
# Drama     3.540997e+10
# Name: Gross, dtype: float64

# %%
# Find the genre with highest avg imdb ratings (Task)
Genre["IMDB_Rating"].mean().sort_values(ascending=False).head(1)
# Out:
# Genre
# Western    8.35
# Name: IMDB_Rating, dtype: float64

# %%
# Find the most earning actor-director combo
df.groupby(["Star1", "Director"])

# %%
# find the highest rated movie of each genre (Hint -> idxmax())

# %% [markdown]
# *Happy Coding 🎉🎉*
