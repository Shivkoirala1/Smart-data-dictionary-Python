# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Consider the following Python dictionary data and Python list labels:

# %%
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'], 
        'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2], 
        'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']

# %% [markdown]
# #### *i) Create a DataFrame birds from the above dictionary data which has the index labels.*

# %%
# Code here
df = pd.DataFrame(data, index = labels)
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      NaN
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       2      yes

# %% [markdown]
# #### *ii) Display basic information about the dataFrame.*

# %%
# Code here
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11 entries, a to k
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birds     11 non-null     str
#  1   age       9 non-null      float64
#  2   visits    11 non-null     int64
#  3   priority  10 non-null     str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 561.0 bytes

# %% [markdown]
# #### *iii) Show Alternate rows of the dataframe.*

# %%
# Display alternate rows 
df[::2]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# i  spoonbills  8.0       3       no
# k      Cranes  3.5       2      yes

# %% [markdown]
# #### *iv) Show only rows [1st, 3rd, 7th] from columns ['bird', 'age']*

# %%
# Code here

selected_rows = birds.iloc[[0, 2, 6]][['birds', 'age']]

print(selected_rows)
# Out:
#      birds  age
# a   Cranes  3.5
# c  plovers  1.5
# g  plovers  5.5

# %% [markdown]
# #### *v) Select rows where the number of visits is less than 4.*

# %%
# Code here
filtered_rows = birds[birds['visits'] < 4]

print(filtered_rows)
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       2      yes

# %% [markdown]
# #### *vi) Select all rows with nan values in age and priority column.*

# %%
# Code here
# df = pd.DataFrame(data)
# filtered_row = df[df['age'].isna() | df['priority'].isna()]

# print(filtered_row)
df[(df['age'].isna()) | (df['priority'].isna())]
# Out:
#         birds  age  visits priority
# d  spoonbills  NaN       4      NaN
# h      Cranes  NaN       2      yes

# %% [markdown]
# #### *vii) Fill nan with respective series mode value.*

# %%
# Code here
age_mode = df ["age"].mode()[0]
pmode = df["priority"].mode()[0]

df["age"] = df ["age"].fillna(age_mode)
df["priority"] = df["priority"].fillna(pmode)
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  3.5       4       no
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  3.5       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       2      yes

# %% [markdown]
# #### *viii) Find the total number of visits of the bird Cranes.*

# %%
# Code here

df[df['birds'] == 'Cranes']['visits'].sum()
# Out:
# np.int64(14)

# %% [markdown]
# #### *ix) Find the number of each type of birds in dataframe.*

# %%
# Code here
df['birds'].value_counts()
# Out:
# birds
# Cranes        5
# spoonbills    4
# plovers       2
# Name: count, dtype: int64

# %% [markdown]
# #### *x) Print no of duplicate rows.*

# %%
# Code here
print(df.duplicated().sum()) 
print(df[df.duplicated()])
# Out:
# 2
#     birds  age  visits priority
# h  Cranes  3.5       2      yes
# k  Cranes  3.5       2      yes

# %% [markdown]
# #### *xi) Drop Duplicates rows and make this changes permanent. Show dataframe after changes.*

# %%
# Code here 
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  3.5       4       no
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# ### 2.  Download this dataset: `IPL dataset from 2008 to 2022.`
# https://drive.google.com/file/d/10_eb5Dy81iXO-aTd4LDRUk85jHVLsqGb/view?usp=drive_link
#
# `After downloading, kindly upload the dataset to the same folder that contains this file.`

# %%
# Read dataset and display top 5 rows
df = pd.read_csv("IPL_Matches_2008_2022.csv")
df.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %% [markdown]
# ##### *In IPL matches dataset some teams name has changed. We will have to consider them as same.*
#
# Change `Delhi Daredevils` -> `Delhi Capitals` <br>
# Change `Kings XI Punjab` -> `Punjab Kings` <br>
# Change `Rising Pune Supergiants` -> `Rising Pune Supergiant` <br>
# *We need to make changes accordingly. Consider current name for each teams.*
#
# Be careful `Gujrat Titans` and `Gujrat Lions` are different teams.

# %%
# Code here 
df.replace({'Delhi Daredevils': 'Delhi Capitals', 
            'Kings XI Punjab':'Punjab Kings', 
            'Rising Pune Supergiants':'Rising Pune Supergiant'},
          inplace = True)
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Delhi Capitals                 114
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Pune Warriors                   23
# Gujarat Lions                   16
# Rising Pune Supergiant          14
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %% [markdown]
# #### *i) Display the bar chart of top 5 teams who have played maximum number of matches in the IPL.*
# `Hint:` Be careful the data is divided in 2 different cols(Team 1 and Team 2)

# %%
# Code here 
games_played_as_team1 = df['Team1'].value_counts()
games_played_as_team2 = df['Team2'].value_counts()
total_games_played = games_played_as_team1 + games_played_as_team2
total_games_played
# Out:
# Team1
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                 224
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                   218
# Rajasthan Royals               192
# Rising Pune Supergiant          30
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %%
total_games_played.sort_values(ascending = False)[:5].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Team1'>

# %% [markdown]
# #### *ii) Player who got Most no. of player of the match award playing against Mumbai Indians.*

# %%
# Code here 
games_played_by_MI = df[(df["Team1"] == "Mumbai Indians") | (df['Team2'] == "Mumbai Indians")]
games_losed_by_MI = games_played_by_MI[games_played_by_MI["WinningTeam"] != "Mumbai Indians"]
games_losed_by_MI['Player_of_Match'].value_counts().idxmax()
# Out:
# 'KL Rahul'

# %% [markdown]
# #### *iii) Find out the top 7 cities where the matches of Kolkata Knight Riders are played frequently <br> and plot the result as bar chart.*

# %%
# Code here 
df[(df["Team1"] == "Kolkata Knight Riders") | (df['Team2'] == "Kolkata Knight Riders ")]['City'].value_counts()[:7].plot(kind = "bar")
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# #### *iv) Find out the average margin for the team Mumbai Indians for only the session 2011.*

# %%
# Code here
df[(df["Season"] == '2011') & (df['WinningTeam'] == "Mumbai Indians")]['Margin'].mean()
# Out:
# np.float64(15.4)

# %% [markdown]
# #### *v) Team1 vs Team2 Dashbord*

# %% [markdown]
# *Create a function which will take two string(name of two teams) as input. Show win Loss record between them <br>
# and player getting most player of the match award in matches between these two teams.* <br>
# `team1_vs_team2('Kolkata Knight Riders','Chennai Super Kings')`

# %%
# Code here 
def team1_vs_team2(team1, team2):
    condition = ((df["Team1"] == team1) & (df["Team2"] == team2)) | ((df["Team1"] == team2) & (df["Team2"] == team1))
    games_played = df[condition]
    win_loss_record = games_played['WinningTeam'].value_counts()
    player_of_match = games_played['Player_of_Match'].value_counts().idxmax()
    print(player_of_match)
    print(win_loss_record)
    
team1_vs_team2('Kolkata Knight Riders','Chennai Super Kings')
# Out:
# RA Jadeja
# WinningTeam
# Chennai Super Kings      17
# Kolkata Knight Riders     9
# Name: count, dtype: int64
